# %% [markdown]
# <a href="https://colab.research.google.com/github/paulohgola/machine-learning/blob/main/space_launch_analysis_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sistema de Verificação de Decolagem Espacial - FIAP - FASE1
#
# Projeto acadêmico que simula a análise de telemetria de uma nave antes da decolagem.
#
# Autores:Ana Carolina Freire Mafra, Vitor De Araujo Ferreira, Vinicius Daniel De Borba, Daniel Guimarães Barreto, Paulo Henrique da Silva Gola,
#
# Gerado em: 2026-03-09
#
# Este notebook cobre:
# - Organização da telemetria
# - Algoritmo de verificação
# - Implementação em Python
# - Análise energética
# - Identificação de anomalias

# %% [markdown]
# ## 1️⃣ Organização dos Dados de Telemetria
#
# Os sensores da nave fornecem os seguintes dados:
#
# - Temperatura interna
# - Temperatura externa
# - Integridade estrutural
# - Nível de energia
# - Pressão dos tanques
# - Status dos módulos críticos

# %%
# Simulação dos dados recebidos da telemetria

//temperatura_interna = 22
temperatura_externa = -40
integridade_estrutural = 1
energia_percentual = 85
pressao_tanques = 5.2
status_modulos = 'OK'

print('Dados de Telemetria Recebidos:')
print('Temperatura interna:', temperatura_interna)
print('Temperatura externa:', temperatura_externa)
print('Integridade estrutural:', integridade_estrutural)
print('Energia (%):', energia_percentual)
print('Pressão dos tanques:', pressao_tanques)
print('Status módulos:', status_modulos)//
# Out:
# Dados de Telemetria Recebidos:
# Temperatura interna: 22
# Temperatura externa: -40
# Integridade estrutural: 1
# Energia (%): 85
# Pressão dos tanques: 5.2
# Status módulos: OK

# %% [markdown]
# ## 2️⃣ Algoritmo de Verificação
#
# O sistema verifica se todos os parâmetros estão dentro de faixas seguras.
#
# Se todos estiverem corretos → **PRONTO PARA DECOLAR**
#
# Caso contrário → **DECOLAGEM ABORTADA**

# %%
# Verificação dos parâmetros de segurança

//if (18 <= temperatura_interna <= 27 and
    -120 <= temperatura_externa <= 50 and
    integridade_estrutural == 1 and
    energia_percentual >= 70 and
    4 <= pressao_tanques <= 6 and
    status_modulos == 'OK'):

    resultado = 'PRONTO PARA DECOLAR 🚀'

else:

    resultado = 'DECOLAGEM ABORTADA ❌'

print('Resultado da verificação:', resultado)//

# %% [markdown]
# ## 3️⃣ Análise Energética
#
# Nesta etapa calculamos a autonomia energética da nave considerando:
#
# - Capacidade total
# - Carga atual
# - Consumo na decolagem
# - Perdas energéticas

# %%
# Dados energéticos

//capacidade_total = 1200
carga_percentual = 85
consumo_decolagem = 300
perda_percentual = 0.05

# Cálculos

energia_disponivel = capacidade_total * (carga_percentual / 100)
perdas = energia_disponivel * perda_percentual
energia_real = energia_disponivel - perdas
energia_restante = energia_real - consumo_decolagem

print('Energia disponível:', energia_disponivel, 'kWh')
print('Perdas energéticas:', perdas, 'kWh')
print('Energia real:', energia_real, 'kWh')
print('Energia restante após decolagem:', energia_restante, 'kWh')//

# %% [markdown]
# ## 4️⃣ Identificação de Possíveis Anomalias
#
# Aqui simulamos uma análise simples para detectar possíveis riscos.

# %%
anomalias = []

//if energia_percentual < 60:
    anomalias.append('Energia abaixo do nível seguro')

if pressao_tanques < 4 or pressao_tanques > 6:
    anomalias.append('Pressão anormal nos tanques')

if integridade_estrutural == 0:
    anomalias.append('Falha estrutural detectada')

if status_modulos != 'OK':
    anomalias.append('Falha em módulo crítico')

if anomalias:
    print('⚠️ Anomalias detectadas:')
    for a in anomalias:
        print('-', a)
else:
    print('Nenhuma anomalia detectada.')//

# %% [markdown]
# ## 5️⃣ Conclusão
#
# Este sistema simula a análise automatizada de telemetria antes da decolagem de uma nave.
#
# A utilização de algoritmos e monitoramento automatizado aumenta significativamente a segurança das missões espaciais, permitindo identificar falhas antes que elas causem acidentes.
#
# Ferramentas como Python e análise assistida por inteligência artificial podem contribuir para decisões mais seguras e rápidas em ambientes críticos.
