# %%
import pandas as pd

df = pd.read_csv("pizzas.csv")
df
# Out:
#    diametro  preco
# 0        25     50
# 1        30     55
# 2        35     60
# 3        40     65
# 4        45     70
# 5        50     75
# 6        55     80
# 7        60     85
# 8        65     90
# 9        70     95

# %%
df.plot(kind='scatter', x="diametro", y="preco");
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from sklearn import linear_model

modelo = linear_model.LinearRegression()
x = df[["diametro"]]
y = df[["preco"]]

modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
print(modelo.predict([[25]])[0][0])
# Out:
# 50.0
# c:\Users\brunn\Documents\machine learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
